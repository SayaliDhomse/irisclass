# %% [markdown]
# Import Dataset

# %% [markdown]
#  **Name** - Sayali Dhomse
#
# **Task** - Iris Flower Detection

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-086838f4-8959-41f1-865d-ecf9f0028e42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-086838f4-8959-41f1-865d-ecf9f0028e42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Import Library

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import sklearn
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame

# %%
print('Python: {}'.format(sys.version))
print('pandas: {}'.format(pd.__version__))
print('numpy: {}'.format(np.__version__))
print('matplotlib: {}'.format(matplotlib.__version__))
print('Scikit-learn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# pandas: 1.5.3
# numpy: 1.23.5
# matplotlib: 3.7.1
# Scikit-learn: 1.2.2

# %%
col = ['sepal_length', 'sepal_width','petal_length', 'petal_width', 'Species']
iris = pd.read_csv('Iris.csv', names=col)
print(iris)
# Out:
#       sepal_length   sepal_width   petal_length   petal_width         Species
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [151 rows x 5 columns]

# %%
print(iris.shape)
# Out:
# (151, 5)

# %%
print(iris.describe())
# Out:
#        sepal_length sepal_width petal_length petal_width        class
# count           151         151          151         151          151
# unique           36          24           44          23            4
# top             5.0         3.0          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
print(iris.tail(20))
# Out:
#     sepal_length sepal_width petal_length petal_width         Species
# 131          7.4         2.8          6.1         1.9  Iris-virginica
# 132          7.9         3.8          6.4         2.0  Iris-virginica
# 133          6.4         2.8          5.6         2.2  Iris-virginica
# 134          6.3         2.8          5.1         1.5  Iris-virginica
# 135          6.1         2.6          5.6         1.4  Iris-virginica
# 136          7.7         3.0          6.1         2.3  Iris-virginica
# 137          6.3         3.4          5.6         2.4  Iris-virginica
# 138          6.4         3.1          5.5         1.8  Iris-virginica
# 139          6.0         3.0          4.8         1.8  Iris-virginica
# 140          6.9         3.1          5.4         2.1  Iris-virginica
# 141          6.7         3.1          5.6         2.4  Iris-virginica
# 142          6.9         3.1          5.1         2.3  Iris-virginica
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, Id to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  151 non-null    object
#  1   sepal_width   151 non-null    object
#  2   petal_length  151 non-null    object
#  3   petal_width   151 non-null    object
#  4   Species       151 non-null    object
# dtypes: object(5)
# memory usage: 7.1+ KB

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64

# %%
iris.head()
# Out:
#      sepal_length   sepal_width   petal_length   petal_width      Species
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa

# %% [markdown]
# #Use Heatmap to see correlation.

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,cmap="Oranges_r")
plt.show()
# Out:
# <ipython-input-40-f4dbd267e0c5>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
data = [1, 2, 3, 4]

#create DataFrame
df = pd.DataFrame({'DataFrame':[25, 12, 15, 14],
                   'assists': [5, 7, 13, 12]})

# %%
import plotly.express as px
fig=px.scatter(iris,x="sepal_length",y= "sepal_width", color="Species")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.pairplot(df, hue = "species",markers = "x")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.scatterplot(x='sepal_length',y='petal_length',data=df,hue='species')
plt.subplot(1,2,2)
sns.scatterplot(x='sepal_width',y='petal_width',data=df,hue='species')
plt.show()

# %%
# Check value counts
df["species"].value_counts().plot(kind="pie",autopct="%1.1f%%",shadow=True, figsize=(5,5))
plt.title("Percentage values in each Species", fontsize=12,c="g")
plt.ylabel("",fontsize=10,c="r")
plt.show()

# %%
sns.distplot(df["sepal_length"])
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.distplot(df["sepal_length"],color="y").set_title("SepalLength interval")

plt.subplot(2,2,2)
sns.distplot(df["sepal_width"],color="r").set_title("SepalWidth interval")

plt.subplot(2,2,3)
sns.distplot(df["petal_length"],color="g").set_title("PetalLength interval")

plt.subplot(2,2,4)
sns.distplot(df["petal_width"],color="b").set_title("PetalWidth interval")

plt.show()
# Out:
# <ipython-input-82-b52d2152bfdf>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-82-b52d2152bfdf>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-82-b52d2152bfdf>:7: UserWarning:
#
#
#
# ...
